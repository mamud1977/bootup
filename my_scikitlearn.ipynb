# %% [markdown]
# <a href="https://colab.research.google.com/github/mamud1977/bootup/blob/main/my_scikitlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome to Learning basic ScikitLearn.....')
# Out:
# Welcome to Learning basic ScikitLearn.....

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

data =  np.random.randint(0,100,(10,2))
data
# Out:
# array([[ 4, 82],
#        [31, 65],
#        [19,  3],
#        [64,  9],
#        [89, 47],
#        [50, 92],
#        [13, 53],
#        [93, 74],
#        [54,  7],
#        [44, 13]])

# %%
scaler_model = MinMaxScaler()
type(scaler_model)

scaler_model.fit(data)

scaler_model.transform(data)
# Out:
# array([[0.27692308, 1.        ],
#        [0.41538462, 0.        ],
#        [1.        , 0.25757576],
#        [0.53846154, 0.01515152],
#        [0.        , 0.24242424],
#        [0.15384615, 0.06060606],
#        [0.50769231, 0.09090909],
#        [0.26153846, 0.65151515],
#        [0.26153846, 0.78787879],
#        [0.        , 0.39393939]])

# %%
data = pd.DataFrame(data = np.random.randint(0,100, (50,4)),columns = ['f1','f2','f3','Label'] )
data
# Out:
#     f1  f2  f3  Label
# 0    4  16  40     16
# 1   73   9  30     69
# 2   81  58  64     39
# 3   95  13  24      4
# 4   77   3  96     46
# 5   89  61  42     89
# 6   37  46  69     38
# 7   56  28  56     23
# 8   58  56  75     35
# 9   22  20  34     91
# 10  20  64  59     45
# 11  18  81  87     33
# 12  82  12  76     19
# 13  32  24  80     31
# 14  91   2  34     30
# 15   7  45  74     46
# 16  38  59  44     35
# 17  27  27  89     35
# 18  75  51  48     77
# 19  23  73  32     22
# 20  74  46  62     82
# 21  29  68  63     83
# 22  51  31  14     90
# 23  52  10   1     30
# 24  12  88  59     62
# 25  54  94  41      6
# 26   1  95  23     31
# 27  47  86  19     64
# 28  10  18   8     54
# 29  50  33  60     42
# 30  41  70  49     21
# 31  57  97  91     62
# 32  74   3  13      1
# 33  62  52  64     54
# 34  10  35  94     46
# 35  50  25   2     80
# 36  12  42  77     48
# 37  27  97  72     44
# 38  88  16  36     50
# 39   0  22  52     51
# 40   4  83  81      5
# 41  37  46  20     22
# 42  93  37  87     61
# 43   6  42  51     65
# 44   9  24  41     94
# 45  81  24   5     86
# 46  11  71  31      8
# 47   6  79  71     42
# 48  84  45  52     97
# 49  30  95  53     24

# %%
X = data[['f1','f2','f3']]
X
# Out:
#     f1  f2  f3
# 0    4  16  40
# 1   73   9  30
# 2   81  58  64
# 3   95  13  24
# 4   77   3  96
# 5   89  61  42
# 6   37  46  69
# 7   56  28  56
# 8   58  56  75
# 9   22  20  34
# 10  20  64  59
# 11  18  81  87
# 12  82  12  76
# 13  32  24  80
# 14  91   2  34
# 15   7  45  74
# 16  38  59  44
# 17  27  27  89
# 18  75  51  48
# 19  23  73  32
# 20  74  46  62
# 21  29  68  63
# 22  51  31  14
# 23  52  10   1
# 24  12  88  59
# 25  54  94  41
# 26   1  95  23
# 27  47  86  19
# 28  10  18   8
# 29  50  33  60
# 30  41  70  49
# 31  57  97  91
# 32  74   3  13
# 33  62  52  64
# 34  10  35  94
# 35  50  25   2
# 36  12  42  77
# 37  27  97  72
# 38  88  16  36
# 39   0  22  52
# 40   4  83  81
# 41  37  46  20
# 42  93  37  87
# 43   6  42  51
# 44   9  24  41
# 45  81  24   5
# 46  11  71  31
# 47   6  79  71
# 48  84  45  52
# 49  30  95  53

# %%
Y = data[['Label']]
Y
# Out:
#     Label
# 0      16
# 1      69
# 2      39
# 3       4
# 4      46
# 5      89
# 6      38
# 7      23
# 8      35
# 9      91
# 10     45
# 11     33
# 12     19
# 13     31
# 14     30
# 15     46
# 16     35
# 17     35
# 18     77
# 19     22
# 20     82
# 21     83
# 22     90
# 23     30
# 24     62
# 25      6
# 26     31
# 27     64
# 28     54
# 29     42
# 30     21
# 31     62
# 32      1
# 33     54
# 34     46
# 35     80
# 36     48
# 37     44
# 38     50
# 39     51
# 40      5
# 41     22
# 42     61
# 43     65
# 44     94
# 45     86
# 46      8
# 47     42
# 48     97
# 49     24

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_Train, Y_test = train_test_split (X,Y, test_size = 0.2, random_state=50)

# %%
X_train.shape
# Out:
# (40, 3)

# %%
X_test
# Out:
#     f1  f2  f3
# 34  10  35  94
# 36  12  42  77
# 1   73   9  30
# 38  88  16  36
# 8   58  56  75
# 16  38  59  44
# 35  50  25   2
# 13  32  24  80
# 29  50  33  60
# 24  12  88  59
