# %% [markdown]
# <a href="https://colab.research.google.com/github/mamud1977/bootup/blob/main/AI_data_analysis_%26_visualization_seaborns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Analysis & Visual Plotting with Seaborn

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/rainfall.csv')
df.tail(4)
# Out:
#         num  altitude  sep  oct  nov  dec  jan  feb  mar  apr  may     name  \
# 165  330370      -375  0.1    6   10   20   22   19   11    6  1.3    Kalya
# 166  337000      -390  0.0    5    3   10    7    7    7    3  0.5     Sdom
# 167  345005        80  0.4    2    2    6    5    4    5    2  0.4  Yotveta
# 168  347702        11  0.0    4    2    5    4    3    3    2  1.0    Eilat
#
#            x_utm        y_utm
# 165  733547.7554  3515345.019
# 166  728245.6354  3435502.691
# 167  700626.2988  3307818.515
# 168  689139.3140  3270290.211

# %%
df.columns
# Out:
# Index(['num', 'altitude', 'sep', 'oct', 'nov', 'dec', 'jan', 'feb', 'mar',
#        'apr', 'may', 'name', 'x_utm', 'y_utm'],
#       dtype='object')

# %%
sns.set_style('whitegrid')
sns.histplot(df["dec"], kde=True, color="m")
# Out:
# <Axes: xlabel='dec', ylabel='Count'>

# %%
sns.pairplot(df)
